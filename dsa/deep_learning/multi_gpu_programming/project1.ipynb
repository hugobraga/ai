# %%
# !python dsa_script-01.py

# %%
#!lscpu |grep 'Model name' #linux
# !sysctl -a | grep machdep.cpu #mac os

# %%
# !pip install -q --upgrade numba

# %%
# !python dsa_script-02.py

# %%
# !python dsa_script-02.py

# %%
# !python dsa_script-03.py

# %%
# !python dsa_script-04.py

# %%
# !python dsa_script-05.py

# %%
# !python p1-01-opencv.py

# %%
# !python p1-02-filtro.py

# %%
# !python p1-03-numba.py

# %%
# !python p1-04-cuda.py
