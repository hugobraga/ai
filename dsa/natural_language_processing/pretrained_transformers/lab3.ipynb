# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
# # <font color='blue'>Processamento de Linguagem Natural com Transformers</font>
#
# ## <font color='blue'>Lab 3</font>
# ## <font color='blue'>Geração de Texto com Arquitetura GPT via API em Linguagem Python</font>

# %% [markdown]
# ![DSA](images/Lab3.png)

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.10.14

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
# !pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (24.2)

# %%
# !pip install -q openai
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (1.50.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from openai) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)

# %%
# Importação das bibliotecas necessárias
# https://pypi.org/project/openai/
import openai
print(openai.__file__)
print(openai.__version__)
# Out:
# /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages/openai/__init__.py
# 1.50.2

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# Author: Data Science Academy
#
# platform: 1.0.8
# sys     : 3.10.14 (main, May  6 2024, 14:42:37) [Clang 14.0.6 ]
# openai  : 1.50.2

# %%
# API KEY
# Solicita ao usuário que insira a API Key
api_key = input("Por favor, insira sua API Key da OpenAI: ")
openai.api_key = api_key

# %% [markdown]
# ## Geração de Texto e Parâmetros de Customização

# %%
# Gera o texto utilizando a nova interface da API
client = openai.OpenAI(api_key=api_key)
response = client.chat.completions.create(
    model="gpt-3.5-turbo",  # Atualize para o modelo apropriado (por exemplo, gpt-3.5-turbo)
    messages=[
        {"role": "system", "content": "Você é um assistente que cria histórias."},
        {"role": "user", "content": "Era uma vez"}
    ],
    temperature=0.5,  # Controle de aleatoriedade do texto gerado
    max_tokens=150    # Quantidade máxima de tokens para gerar
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[12], line 4
#       2 client = openai.OpenAI(api_key=api_key)
#       3 client.models.list()
# ----> 4 response = client.chat.completions.create(
#       5     model="gpt-3.5-turbo",  # Atualize para o modelo apropriado (por exemplo, gpt-3.5-turbo)
#       6     messages=[
#       7         {"role": "system", "content": "Você é um assistente que cria histórias."},
#       8         {"role": "user", "content": "Era uma vez"}
#       9     ],
#      10     temperature=0.5,  # Controle de aleatoriedade do texto gerado
#      11     max_tokens=150    # Quantidade máxima de tokens para gerar
#      12 )
#
# File /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages/openai/_utils/_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages/openai/resources/chat/completions.py:704, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     668 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     669 def create(
#     670     self,
#    (...)
#     701     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     702 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     703     validate_response_format(response_format)
# --> 704     return self._post(
#     705         "/chat/completions",
#     706         body=maybe_transform(
#     707             {
#     708                 "messages": messages,
#     709                 "model": model,
#     710                 "frequency_penalty": frequency_penalty,
#     711                 "function_call": function_call,
#     712                 "functions": functions,
#     713                 "logit_bias": logit_bias,
#     714                 "logprobs": logprobs,
#     715                 "max_completion_tokens": max_completion_tokens,
#     716                 "max_tokens": max_tokens,
#     717                 "n": n,
#     718                 "parallel_tool_calls": parallel_tool_calls,
#     719                 "presence_penalty": presence_penalty,
#     720                 "response_format": response_format,
#     721                 "seed": seed,
#     722                 "service_tier": service_tier,
#     723                 "stop": stop,
#     724                 "stream": stream,
#     725                 "stream_options": stream_options,
#     726                 "temperature": temperature,
#     727                 "tool_choice": tool_choice,
#     728                 "tools": tools,
#     729                 "top_logprobs": top_logprobs,
#     730                 "top_p": top_p,
#     731                 "user": user,
#     732             },
#     733             completion_create_params.CompletionCreateParams,
#     734         ),
#     735         options=make_request_options(
#     736             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     737         ),
#     738         cast_to=ChatCompletion,
#     739         stream=stream or False,
#     740         stream_cls=Stream[ChatCompletionChunk],
#     741     )
#
# File /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages/openai/_base_client.py:1270, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1256 def post(
#    1257     self,
#    1258     path: str,
#    (...)
#    1265     stream_cls: type[_StreamT] | None = None,
#    1266 ) -> ResponseT | _StreamT:
#    1267     opts = FinalRequestOptions.construct(
#    1268         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1269     )
# -> 1270     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages/openai/_base_client.py:947, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     944 else:
#     945     retries_taken = 0
# --> 947 return self._request(
#     948     cast_to=cast_to,
#     949     options=options,
#     950     stream=stream,
#     951     stream_cls=stream_cls,
#     952     retries_taken=retries_taken,
#     953 )
#
# File /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages/openai/_base_client.py:1036, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1034 if remaining_retries > 0 and self._should_retry(err.response):
#    1035     err.response.close()
# -> 1036     return self._retry_request(
#    1037         input_options,
#    1038         cast_to,
#    1039         retries_taken=retries_taken,
#    1040         response_headers=err.response.headers,
#    1041         stream=stream,
#    1042         stream_cls=stream_cls,
#    1043     )
#    1045 # If the response is streamed then we need to explicitly read the response
#    1046 # to completion before attempting to access the response text.
#    1047 if not err.response.is_closed:
#
# File /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages/openai/_base_client.py:1085, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1081 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1082 # different thread if necessary.
#    1083 time.sleep(timeout)
# -> 1085 return self._request(
#    1086     options=options,
#    1087     cast_to=cast_to,
#    1088     retries_taken=retries_taken + 1,
#    1089     stream=stream,
#    1090     stream_cls=stream_cls,
#    1091 )
#
# File /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages/openai/_base_client.py:1036, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1034 if remaining_retries > 0 and self._should_retry(err.response):
#    1035     err.response.close()
# -> 1036     return self._retry_request(
#    1037         input_options,
#    1038         cast_to,
#    1039         retries_taken=retries_taken,
#    1040         response_headers=err.response.headers,
#    1041         stream=stream,
#    1042         stream_cls=stream_cls,
#    1043     )
#    1045 # If the response is streamed then we need to explicitly read the response
#    1046 # to completion before attempting to access the response text.
#    1047 if not err.response.is_closed:
#
# File /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages/openai/_base_client.py:1085, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1081 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1082 # different thread if necessary.
#    1083 time.sleep(timeout)
# -> 1085 return self._request(
#    1086     options=options,
#    1087     cast_to=cast_to,
#    1088     retries_taken=retries_taken + 1,
#    1089     stream=stream,
#    1090     stream_cls=stream_cls,
#    1091 )
#
# File /opt/anaconda3/envs/DSA2/lib/python3.10/site-packages/openai/_base_client.py:1051, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1048         err.response.read()
#    1050     log.debug("Re-raising status error")
# -> 1051     raise self._make_status_error_from_response(err.response) from None
#    1053 return self._process_response(
#    1054     cast_to=cast_to,
#    1055     options=options,
#    (...)
#    1059     retries_taken=retries_taken,
#    1060 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# O método openai.Completion.create() aceita vários parâmetros que permitem controlar a saída do texto gerado. Aqui estão alguns dos parâmetros mais comumente usados:
#
# **engine**: O ID do modelo que você deseja usar para gerar o texto. Por exemplo, "text-davinci-003" para o GPT-3 (versão mais recente).
#
# **prompt**: O texto inicial que você deseja que o modelo use como ponto de partida para gerar o texto.
#
# **temperature**: Um valor entre 0 e 1 que controla a aleatoriedade do texto gerado. Valores mais altos resultam em texto mais aleatório, enquanto valores mais baixos resultam em texto mais determinístico.
#
# **max_tokens**: O número máximo de tokens que o modelo deve gerar. Note que o modelo pode gerar menos tokens se chegar a uma conclusão natural mais cedo.
#
# **top_p**: Uma alternativa para o parâmetro de temperatura. Este parâmetro controla a diversidade do texto gerado, ao manter apenas as previsões cuja probabilidade acumulada exceda o valor do parâmetro top_p.
#
# **frequency_penalty**: Penalidade para palavras frequentes. O valor deve estar entre -1,0 e 1,0. Valores mais altos desencorajam as palavras mais comuns.
#
# **presence_penalty**: Penalidade para palavras novas. O valor deve estar entre -1,0 e 1,0. Valores mais altos desencorajam as palavras que ainda não apareceram no texto atual.
#
# **stop_sequences**: Uma lista de sequências onde a API deve parar de gerar mais tokens.
#
# **n**: O número de diferentes conclusões a serem geradas a partir do prompt dado.
#
# Estes parâmetros podem alterar significativamente a qualidade e o estilo do texto gerado. Você pode querer experimentar diferentes combinações de parâmetros para ver o que funciona melhor para o seu caso de uso específico.
#
# Além disso, a disponibilidade dessas opções pode variar dependendo da versão específica do modelo e da API da OpenAI que você está usando. Portanto, é sempre uma boa ideia verificar a documentação oficial para obter as informações mais atualizadas.
#
# https://platform.openai.com/docs/introduction

# %%
print(response)

# %%
# Exibindo o texto gerado
print(response.choices[0].text.strip())

# %%
# Obtém a lista de modelos disponíveis
client.models.list()
# Out:
# SyncPage[Model](data=[Model(id='tts-1-hd-1106', created=1699053533, object='model', owned_by='system'), Model(id='tts-1-hd', created=1699046015, object='model', owned_by='system'), Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'), Model(id='text-embedding-3-large', created=1705953180, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-0125', created=1706048358, object='model', owned_by='system'), Model(id='gpt-4o-mini', created=1721172741, object='model', owned_by='system'), Model(id='gpt-4o-mini-2024-07-18', created=1721172717, object='model', owned_by='system'), Model(id='gpt-3.5-turbo', created=1677610602, object='model', owned_by='openai'), Model(id='tts-1-1106', created=1699053241, object='model', owned_by='system'), Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'), Model(id='tts-1', created=1681940951, object='model', owned_by='openai-internal'), Model(id='gpt-3.5-turbo-16k', created=1683758102, object='model', owned_by='openai-internal'), Model(id='text-embedding-3-small', created=1705948997, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-1106', created=1698959748, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-instruct-0914', created=1694122472, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-instruct', created=1692901427, object='model', owned_by='system'), Model(id='babbage-002', created=1692634615, object='model', owned_by='system'), Model(id='davinci-002', created=1692634301, object='model', owned_by='system'), Model(id='dall-e-3', created=1698785189, object='model', owned_by='system'), Model(id='text-embedding-ada-002', created=1671217299, object='model', owned_by='openai-internal')], object='list')

# %%
# Imprime a lista
for model in response['data']:
    print(model['id'])

# %% [markdown]
# ## Geração de Texto Através de Tradução de Texto

# %%
# Prompt
prompt_text = "Traduza o seguinte texto do inglês para o português: \
'A text is a passage of words that conveys a set of meanings to the person who is reading it.'",

# %%
# Tradução de texto
client = openai.OpenAI(api_key=api_key)
response = client.chat.completions.create(
    model="gpt-3.5-turbo",  # Atualize para o modelo apropriado (por exemplo, gpt-3.5-turbo)
    prompt = prompt_text,
    temperature = 0.5,
    max_tokens = 60,
    n = 2  
)

# %%
# Print
for i, choice in enumerate(response.choices):
    print(f"Conclusão {i+1}: {choice.text.strip()}")

# %% [markdown]
# ## Geração de Texto e Sequências de Parada

# %% [markdown]
# O argumento stop_sequences não é diretamente suportado na função Completion.create(). Em vez disso, você tem que criar uma configuração de tokenização mais personalizada para conseguir o efeito de parar na sequência de tokens desejada.
#
# Implementar tal comportamento exige que você gerencie o processo de conclusão por conta própria, possivelmente gerando uma quantidade menor de texto de cada vez e, em seguida, verificando se a sequência de parada foi atingida antes de gerar mais texto. Isso torna o código um pouco mais complexo. Aqui está um exemplo:

# %%
# Prompt e stop sequence
prompt = "Escreva um poema sobre a primavera"
stop_sequence = "."

# %%
# Resposta da API
client = openai.OpenAI(api_key=api_key)
response = client.chat.completions.create(
    model="gpt-3.5-turbo",  # Atualize para o modelo apropriado (por exemplo, gpt-3.5-turbo)
    engine = "text-davinci-003",
    prompt = prompt,
    temperature = 0.5,
    max_tokens = 20,  # Gerando menos texto de cada vez
)

# %%
# Carrega a resposta da API
text = response.choices[0].text.strip()

# %%
# Loop para continuar gerando até atingir a sequência de parada
client = openai.OpenAI(api_key=api_key)
while not text.endswith(stop_sequence):  
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",  # Atualize para o modelo apropriado (por exemplo, gpt-3.5-turbo)
        prompt = prompt + text,
        temperature = 0.5,
        max_tokens = 20,
    )
    text += response.choices[0].text.strip()

# %%
print(text)

# %% [markdown]
# Nota: Esteja ciente de que esta abordagem aumentará o número de chamadas de API que você faz e, portanto, pode ter um impacto no custo do uso da API da OpenAI. Além disso, este exemplo não considera a possibilidade de que a sequência de parada possa aparecer no meio de um lote de texto gerado, então pode haver situações em que isso não funcionará como esperado, requerendo adaptação.

# %% [markdown]
# # Fim
